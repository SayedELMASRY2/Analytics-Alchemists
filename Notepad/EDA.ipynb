# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Optional for better visuals
sns.set(style="whitegrid")

# %% [markdown]
# **Load Data Set**

# %%
 # Upload your CSV file manually

# Load the DataFrame
df = pd.read_csv('Cleaned_Road_Accident_Data.csv')

# Display the first 5 rows
df.head()
# Out:
#   Accident_Index Accident Date Month Day_of_Week  Year  \
# 0  200901BS70001      1/1/2021   Jan    Thursday  2021
# 1  200901VW40005      1/1/2021   Jan    Thursday  2021
# 2  200901VW40001      1/1/2021   Jan    Thursday  2021
# 3  200920K006502      1/1/2021   Jan    Thursday  2021
# 4  200920K007902      1/1/2021   Jan    Thursday  2021
#
#            Junction_Control          Junction_Detail Accident_Severity  \
# 0  Give way or uncontrolled  T or staggered junction           Serious
# 1       Auto traffic signal  T or staggered junction            Slight
# 2  Give way or uncontrolled  T or staggered junction            Slight
# 3  Give way or uncontrolled  T or staggered junction            Slight
# 4  Give way or uncontrolled  T or staggered junction            Slight
#
#     Latitude       Light_Conditions  ...                   Vehicle_Type  \
# 0  51.512273               Daylight  ...                            Car
# ...

# %%
# Overview of columns, data types, and missing values
df.info()

# Basic statistics for numeric columns
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307972 entries, 0 to 307971
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Accident_Index               307972 non-null  object
#  1   Accident Date                307972 non-null  object
#  2   Month                        307972 non-null  object
#  3   Day_of_Week                  307972 non-null  object
#  4   Year                         307972 non-null  int64
#  5   Junction_Control             307972 non-null  object
#  6   Junction_Detail              307972 non-null  object
#  7   Accident_Severity            307972 non-null  object
#  8   Latitude                     307972 non-null  float64
#  9   Light_Conditions             307972 non-null  object
#  10  Local_Authority_(District)   307972 non-null  object
#  11  Carriageway_Hazards          307972 non-null  object
# ...

# %% [markdown]
# **Distribution of Accident_Severity**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Accident_Severity', order=df['Accident_Severity'].value_counts().index)
plt.title('Distribution of Accident Severity')
plt.xlabel('Severity')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Distribution of Day_of_Week**

# %%
plt.figure(figsize=(8, 4))
order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sns.countplot(data=df, x='Day_of_Week', order=order)
plt.title('Accidents per Day of the Week')
plt.xlabel('Day')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Distribution of Season**

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Season', order=df['Season'].value_counts().index, palette='Blues')
plt.title('Accidents per Season', fontsize=14, fontweight='bold')
plt.xlabel('Season', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elsay\AppData\Local\Temp\ipykernel_3488\412408523.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Season', order=df['Season'].value_counts().index, palette='Blues')

# %% [markdown]
# **Distribuion of Speed_limit**

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Speed_limit', order=sorted(df['Speed_limit'].unique()), palette='Blues')
plt.title('Accidents per Speed Limit', fontsize=14, fontweight='bold')
plt.xlabel('Speed Limit (mph)', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elsay\AppData\Local\Temp\ipykernel_3488\4010220939.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Speed_limit', order=sorted(df['Speed_limit'].unique()), palette='Blues')

# %% [markdown]
# **Distribution Number_of_Vehicles**

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['Number_of_Vehicles'], color='skyblue', fliersize=5, linewidth=2)
plt.title('Distribution of Number of Vehicles per Accident', fontsize=14, fontweight='bold')
plt.xlabel('Number of Vehicles', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of Number_of_Casualties**

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['Number_of_Casualties'], color='skyblue', fliersize=5, linewidth=2)
plt.title('Distribution of Number of Casualties per Accident', fontsize=14, fontweight='bold')
plt.xlabel('Number of Casualties', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Moderately right skewed on Number_of_Vehicles column**

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Number_of_Vehicles', order=sorted(df['Number_of_Vehicles'].unique()), palette='Blues')
plt.title('Accidents per Number of Vehicles', fontsize=14, fontweight='bold')
plt.xlabel('Number of Vehicles', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elsay\AppData\Local\Temp\ipykernel_3488\88652234.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Number_of_Vehicles', order=sorted(df['Number_of_Vehicles'].unique()), palette='Blues')

# %% [markdown]
# **Strong right skewed on Number_of_Casualties Column**

# %%
from matplotlib import pyplot as plt
df['Number_of_Casualties'].plot(kind='hist', bins=20, title='Number_of_Casualties')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **Accident Severity Distribution (Weekend Vs Weekday)**

# %%
# Group data by 'Is_Weekend' and 'Accident_Severity' to calculate proportions
severity_weekend = df.groupby('Is_Weekend')['Accident_Severity'].value_counts(normalize=True).unstack()

# Plot a stacked bar chart
plt.figure(figsize=(10, 6))
severity_weekend.plot(
    kind='bar', 
    stacked=True, 
    colormap='viridis', 
    figsize=(10, 6),
    edgecolor='black'  # Add borders to bars
)
plt.title('Accident Severity Distribution (Weekend vs Weekday)', fontsize=16, fontweight='bold')
plt.xlabel('Is Weekend?', fontsize=14)
plt.ylabel('Proportion of Accidents', fontsize=14)
plt.xticks([0, 1], ['Weekday', 'Weekend'], rotation=0, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(
    title='Accident Severity', 
    bbox_to_anchor=(1.05, 1), 
    loc='upper left', 
    fontsize=12,
    title_fontsize=12
)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add gridlines for better readability
plt.tight_layout()
plt.show()

# Show the actual proportions in a table
severity_weekend.round(3)
# Out:
# Accident_Severity  Fatal  Serious  Slight
# Is_Weekend
# False              0.012    0.131   0.857
# True               0.014    0.136   0.850

# %% [markdown]
# **Relationship: Number_of_Vehicles vs Accident_Severity**

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='Accident_Severity', y='Number_of_Vehicles')
plt.title('Number of Vehicles by Accident Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Number of Vehicles')
plt.show()

# %% [markdown]
# **Relationship: Number_of_Casualties vs Accident_Severity**

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='Accident_Severity', y='Number_of_Casualties')
plt.title('Number of Casualties by Accident Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Number of Casualties')
plt.show()

# %% [markdown]
# **Relationship: Speed_limit vs Accident_Severity**

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Accident_Severity', y='Speed_limit', palette='pastel', linewidth=2.5)
plt.title('Speed Limit by Accident Severity', fontsize=16, fontweight='bold')
plt.xlabel('Accident Severity', fontsize=14)
plt.ylabel('Speed Limit (mph)', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # إضافة خطوط شبكية لتحسين القراءة
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elsay\AppData\Local\Temp\ipykernel_3488\493045827.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Accident_Severity', y='Speed_limit', palette='pastel', linewidth=2.5)

# %% [markdown]
# **Relation Weather_Conditions Vs Accident_Severity**

# %%
# Group by Weather_Conditions and Accident_Severity
weather_severity = df.groupby('Weather_Conditions')['Accident_Severity'].value_counts(normalize=True).unstack()

# Plot
weather_severity.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='Blues')
plt.title('Accident Severity Distribution by Weather Conditions')
plt.xlabel('Weather Conditions')
plt.ylabel('Proportion of Accidents')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Accident Severity', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Display raw proportions
weather_severity.round(3)
# Out:
# Accident_Severity      Fatal  Serious  Slight
# Weather_Conditions
# Fine + high winds      0.017    0.137   0.846
# Fine no high winds     0.013    0.137   0.850
# Fog or mist            0.017    0.133   0.850
# Other                  0.009    0.102   0.888
# Raining + high winds   0.015    0.124   0.861
# Raining no high winds  0.011    0.117   0.872
# Snowing + high winds   0.002    0.111   0.888
# Snowing no high winds  0.006    0.085   0.908

# %% [markdown]
# **Relation Accident_Severity Vs Light_Conditions**

# %%
# Group by Light_Conditions and Accident_Severity
light_severity = df.groupby('Light_Conditions')['Accident_Severity'].value_counts(normalize=True).unstack()

# Plot
plt.figure(figsize=(12, 6))
light_severity.plot(
    kind='bar', 
    stacked=True, 
    figsize=(12, 6), 
    colormap='plasma', 
    edgecolor='black'  # Add borders to bars
)
plt.title('Accident Severity Distribution by Light Conditions', fontsize=16, fontweight='bold')
plt.xlabel('Light Conditions', fontsize=14)
plt.ylabel('Proportion of Accidents', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.legend(
    title='Accident Severity', 
    bbox_to_anchor=(1.05, 1), 
    loc='upper left', 
    fontsize=12,
    title_fontsize=12
)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add gridlines for better readability
plt.tight_layout()
plt.show()

# Show proportions
light_severity.round(3)
# Out:
# Accident_Severity            Fatal  Serious  Slight
# Light_Conditions
# Darkness - lighting unknown  0.010    0.122   0.868
# Darkness - lights lit        0.014    0.142   0.844
# Darkness - lights unlit      0.013    0.128   0.859
# Darkness - no lighting       0.039    0.186   0.775
# Daylight                     0.011    0.126   0.863

# %% [markdown]
# **Relation:  Accident_Severity Vs Urban_or_Rural_Area**

# %%
# Group by Urban_or_Rural_Area and Accident_Severity
area_severity = df.groupby('Urban_or_Rural_Area')['Accident_Severity'].value_counts(normalize=True).unstack()

# Plot
area_severity.plot(kind='bar', stacked=True, figsize=(8, 5), colormap='coolwarm')
plt.title('Accident Severity Distribution by Area Type')
plt.xlabel('Area Type')
plt.ylabel('Proportion of Accidents')
plt.xticks(rotation=0)
plt.legend(title='Accident Severity', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Display proportions
area_severity.round(3)
# Out:
# Accident_Severity    Fatal  Serious  Slight
# Urban_or_Rural_Area
# Rural                0.021    0.157   0.821
# Urban                0.008    0.118   0.873

# %% [markdown]
# **Correlation between numeric columns**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select numeric columns
numeric_features = ['Speed_limit', 'Number_of_Vehicles', 'Number_of_Casualties']

# Calculate correlation matrix
corr_matrix = df[numeric_features].corr()

# Plot the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix between Numeric Features')
plt.show()

# %% [markdown]
# **Chi-Square Test for Categorical features**

# %%
from scipy.stats import chi2_contingency

# List of categorical features to test
categorical_features = [
    'Day_of_Week', 'Light_Conditions', 'Weather_Conditions',
    'Urban_or_Rural_Area', 'Time Slot', 'Is_Weekend'
]

# Function to run Chi-Square Test
def chi_square_test(df, feature, target='Accident_Severity'):
    contingency_table = pd.crosstab(df[feature], df[target])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    return p

# Running test for each categorical feature
chi_square_results = {}

for feature in categorical_features:
    p_value = chi_square_test(df, feature)
    chi_square_results[feature] = p_value

# Display results
chi_square_results
# Out:
# {'Day_of_Week': np.float64(1.514743295951088e-129),
#  'Light_Conditions': np.float64(0.0),
#  'Weather_Conditions': np.float64(5.609896290650526e-66),
#  'Urban_or_Rural_Area': np.float64(0.0),
#  'Time Slot': np.float64(0.0),
#  'Is_Weekend': np.float64(8.268825086957099e-10)}
